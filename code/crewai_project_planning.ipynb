# %% [markdown]
# # L1: Automated Project: Planning, Estimation, and Allocation

# %% [markdown]
# <p style="background-color:#fff6e4; padding:15px; border-width:3px; border-color:#f5ecda; border-style:solid; border-radius:6px"> ⏳ <b>Note <code>(Kernel Starting)</code>:</b> This notebook takes about 30 seconds to be ready to use. You may start and watch the video while you wait.</p>

# %% [markdown]
# ## Initial Imports

# %%
# Warning control
import warnings
warnings.filterwarnings('ignore')

# Load environment variables
from helper import load_env
load_env()

import os
import yaml
from crewai import Agent, Task, Crew

# %% [markdown]
# <p style="background-color:#fff6ff; padding:15px; border-width:3px; border-color:#efe6ef; border-style:solid; border-radius:6px"> 💻 &nbsp; <b>Access <code>requirements.txt</code> and <code>helper.py</code> files:</b> 1) click on the <em>"File"</em> option on the top menu of the notebook and then 2) click on <em>"Open"</em>. For more help, please see the <em>"Appendix - Tips and Help"</em> Lesson.</p>

# %% [markdown]
# ## Set OpenAI Model

# %%
os.environ['OPENAI_MODEL_NAME'] = 'gpt-4o-mini'

# %% [markdown]
# ## Loading Tasks and Agents YAML files

# %%
# Define file paths for YAML configurations
files = {
    'agents': 'config/agents.yaml',
    'tasks': 'config/tasks.yaml'
}

# Load configurations from YAML files
configs = {}
for config_type, file_path in files.items():
    with open(file_path, 'r') as file:
        configs[config_type] = yaml.safe_load(file)

# Assign loaded configurations to specific variables
agents_config = configs['agents']
tasks_config = configs['tasks']

# %% [markdown]
# ## Create Pydantic Models for Structured Output

# %%
from typing import List
from pydantic import BaseModel, Field

class TaskEstimate(BaseModel):
    task_name: str = Field(..., description="Name of the task")
    estimated_time_hours: float = Field(..., description="Estimated time to complete the task in hours")
    required_resources: List[str] = Field(..., description="List of resources required to complete the task")

class Milestone(BaseModel):
    milestone_name: str = Field(..., description="Name of the milestone")
    tasks: List[str] = Field(..., description="List of task IDs associated with this milestone")

class ProjectPlan(BaseModel):
    tasks: List[TaskEstimate] = Field(..., description="List of tasks with their estimates")
    milestones: List[Milestone] = Field(..., description="List of project milestones")

# %% [markdown]
# ## Create Crew, Agents and Tasks

# %%
# Creating Agents
project_planning_agent = Agent(
  config=agents_config['project_planning_agent']
)

estimation_agent = Agent(
  config=agents_config['estimation_agent']
)

resource_allocation_agent = Agent(
  config=agents_config['resource_allocation_agent']
)

# Creating Tasks
task_breakdown = Task(
  config=tasks_config['task_breakdown'],
  agent=project_planning_agent
)

time_resource_estimation = Task(
  config=tasks_config['time_resource_estimation'],
  agent=estimation_agent
)

resource_allocation = Task(
  config=tasks_config['resource_allocation'],
  agent=resource_allocation_agent,
  output_pydantic=ProjectPlan # This is the structured output we want
)

# Creating Crew
crew = Crew(
  agents=[
    project_planning_agent,
    estimation_agent,
    resource_allocation_agent
  ],
  tasks=[
    task_breakdown,
    time_resource_estimation,
    resource_allocation
  ],
  verbose=True
)

# %% [markdown]
# ## Crew's Inputs

# %%
from IPython.display import display, Markdown

project = 'Website'
industry = 'Technology'
project_objectives = 'Create a website for a small business'
team_members = """
- John Doe (Project Manager)
- Jane Doe (Software Engineer)
- Bob Smith (Designer)
- Alice Johnson (QA Engineer)
- Tom Brown (QA Engineer)
"""
project_requirements = """
- Create a responsive design that works well on desktop and mobile devices
- Implement a modern, visually appealing user interface with a clean look
- Develop a user-friendly navigation system with intuitive menu structure
- Include an "About Us" page highlighting the company's history and values
- Design a "Services" page showcasing the business's offerings with descriptions
- Create a "Contact Us" page with a form and integrated map for communication
- Implement a blog section for sharing industry news and company updates
- Ensure fast loading times and optimize for search engines (SEO)
- Integrate social media links and sharing capabilities
- Include a testimonials section to showcase customer feedback and build trust
"""

# Format the dictionary as Markdown for a better display in Jupyter Lab
formatted_output = f"""
**Project Type:** {project}

**Project Objectives:** {project_objectives}

**Industry:** {industry}

**Team Members:**
{team_members}
**Project Requirements:**
{project_requirements}
"""
# Display the formatted output as Markdown
display(Markdown(formatted_output))
# Out:
# **Project Type:** Website
#
# **Project Objectives:** Create a website for a small business
#
# **Industry:** Technology
#
# **Team Members:**
#
# - John Doe (Project Manager)
# - Jane Doe (Software Engineer)
# - Bob Smith (Designer)
# - Alice Johnson (QA Engineer)
# - Tom Brown (QA Engineer)
#
# **Project Requirements:**
#
# - Create a responsive design that works well on desktop and mobile devices
# - Implement a modern, visually appealing user interface with a clean look
# - Develop a user-friendly navigation system with intuitive menu structure
# - Include an "About Us" page highlighting the company's history and values
# - Design a "Services" page showcasing the business's offerings with descriptions
# - Create a "Contact Us" page with a form and integrated map for communication
# - Implement a blog section for sharing industry news and company updates
# - Ensure fast loading times and optimize for search engines (SEO)
# - Integrate social media links and sharing capabilities
# - Include a testimonials section to showcase customer feedback and build trust

# %% [markdown]
# ## Kicking off the crew

# %%
# The given Python dictionary
inputs = {
  'project_type': project,
  'project_objectives': project_objectives,
  'industry': industry,
  'team_members': team_members,
  'project_requirements': project_requirements
}

# Run the crew
result = crew.kickoff(
  inputs=inputs
)
# Out:
# # Agent: The Ultimate Project Planner
# ## Task: Carefully analyze the project_requirements for the Website project and break them down into individual tasks. Define each task's scope in detail, set achievable timelines, and ensure that all dependencies are accounted for:
#
# - Create a responsive design that works well on desktop and mobile devices
# - Implement a modern, visually appealing user interface with a clean look
# - Develop a user-friendly navigation system with intuitive menu structure
# - Include an "About Us" page highlighting the company's history and values
# - Design a "Services" page showcasing the business's offerings with descriptions
# - Create a "Contact Us" page with a form and integrated map for communication
# - Implement a blog section for sharing industry news and company updates
# - Ensure fast loading times and optimize for search engines (SEO)
# - Integrate social media links and sharing capabilities
# - Include a testimonials section to showcase customer feedback and build trust
#
#
# Team members:
#
# - John Doe (Project Manager)
# - Jane Doe (Software Engineer)
# - Bob Smith (Designer)
# - Alice Johnson (QA Engineer)
# - Tom Brown (QA Engineer)
#
#
#
#
# # Agent: The Ultimate Project Planner
# ## Final Answer:
# Below is a comprehensive breakdown of the Website project into actionable tasks, including detailed descriptions, timelines, dependencies, and deliverables. Additionally, a Gantt chart accompanies these tasks for visual tracking.
#
# ### Project Breakdown
#
# **1. Requirements Analysis and Planning**
#    - **Description:** Gather detailed requirements from stakeholders. Identify goals for the website project and develop wireframes.
#    - **Timeline:** 1 week (Week 1)
#    - **Dependencies:** None
#    - **Deliverables:** Requirements document, wireframes
#
# **2. Design Phase**
#    - **Task 2.1: Responsive Design Creation**
#      - **Description:** Create a responsive website layout that adapts to different screen sizes.
#      - **Timeline:** 2 weeks (Weeks 2-3)
#      - **Dependencies:** Completion of the requirements analysis
#      - **Deliverables:** Responsive design mockups
#
#    - **Task 2.2: User Interface Design**
#      - **Description:** Develop a modern, visually appealing user interface utilizing a clean look.
#      - **Timeline:** 2 weeks (Weeks 2-3, concurrently with Task 2.1)
#      - **Dependencies:** Completion of wireframes
#      - **Deliverables:** UI design specifications
#
#    - **Task 2.3: Navigation System Design**
#      - **Description:** Create an intuitive menu structure and navigation system for the website.
#      - **Timeline:** 1 week (Week 4)
#      - **Dependencies:** Completion of UI design
#      - **Deliverables:** Navigation flowchart
#
# **3. Development Phase**
#    - **Task 3.1: About Us Page Development**
#      - **Description:** Develop the "About Us" page that highlights the company’s history and values.
#      - **Timeline:** 1 week (Week 5)
#      - **Dependencies:** Completion of responsive design
#      - **Deliverables:** About Us page code
#
#    - **Task 3.2: Services Page Development**
#      - **Description:** Design and develop the "Services" page showcasing the business's offerings.
#      - **Timeline:** 1 week (Week 5)
#      - **Dependencies:** Completion of responsive design
#      - **Deliverables:** Services page code
#
#    - **Task 3.3: Contact Us Page Development**
#      - **Description:** Create the "Contact Us" page, including a contact form and embedded map.
#      - **Timeline:** 1 week (Week 6)
#      - **Dependencies:** Completion of responsive design
#      - **Deliverables:** Contact Us page code
#
#    - **Task 3.4: Blog Section Development**
#      - **Description:** Implement a blog section for publishing industry news and updates.
#      - **Timeline:** 2 weeks (Weeks 6-7)
#      - **Dependencies:** Completion of responsive design
#      - **Deliverables:** Blog section code
#
#    - **Task 3.5: Testimonials Section Development**
#      - **Description:** Develop a testimonials section to display customer feedback.
#      - **Timeline:** 1 week (Week 8)
#      - **Dependencies:** Completion of responsive design
#      - **Deliverables:** Testimonials section code
#
# **4. Testing Phase**
#    - **Task 4.1: Quality Assurance Testing**
#      - **Description:** Perform thorough testing of all website components and functionalities.
#      - **Timeline:** 2 weeks (Weeks 9-10)
#      - **Dependencies:** Completion of all development tasks
#      - **Deliverables:** QA test report
#
#    - **Task 4.2: Load and Performance Testing**
#      - **Description:** Ensure fast loading times and implement SEO optimizations.
#      - **Timeline:** 1 week (Week 10)
#      - **Dependencies:** Completion of development and QA testing
#      - **Deliverables:** Performance test results
#
# **5. Implementation Phase**
#    - **Task 5.1: Social Media Integration**
#      - **Description:** Integrate social media links and sharing capabilities.
#      - **Timeline:** 1 week (Week 11)
#      - **Dependencies:** Completion of development
#      - **Deliverables:** Updated website with social media integrations
#
#    - **Task 5.2: Final Review and Launch**
#      - **Description:** Conduct a final review before launching the website.
#      - **Timeline:** 1 week (Week 12)
#      - **Dependencies:** Completion of QA and load testing
#      - **Deliverables:** Live website
#
# ### Gantt Chart
#
# ```plaintext
# | Task                                | Week 1 | Week 2 | Week 3 | Week 4 | Week 5 | Week 6 | Week 7 | Week 8 | Week 9 | Week 10 | Week 11 | Week 12 |
# |-------------------------------------|--------|--------|--------|--------|--------|--------|--------|--------|--------|---------|---------|---------|
# | Requirements Analysis and Planning   |   X    |        |        |        |        |        |        |        |        |         |         |         |
# | Responsive Design Creation           |        |   X    |   X    |        |        |        |        |        |        |         |         |         |
# | User Interface Design                |        |   X    |   X    |        |        |        |        |        |        |         |         |         |
# | Navigation System Design             |        |        |        |   X    |        |        |        |        |        |         |         |         |
# | About Us Page Development            |        |        |        |        |   X    |        |        |        |        |         |         |         |
# | Services Page Development            |        |        |        |        |   X    |        |        |        |        |         |         |         |
# | Contact Us Page Development          |        |        |        |        |        |   X    |        |        |        |         |         |         |
# | Blog Section Development             |        |        |        |        |        |   X    |   X    |        |        |         |         |         |
# | Testimonials Section Development      |        |        |        |        |        |        |        |   X    |        |         |         |         |
# | Quality Assurance Testing            |        |        |        |        |        |        |        |        |   X    |    X    |         |         |
# | Load and Performance Testing         |        |        |        |        |        |        |        |        |        |    X    |         |         |
# | Social Media Integration             |        |        |        |        |        |        |        |        |        |         |     X   |         |
# | Final Review and Launch             |        |        |        |        |        |        |        |        |        |         |         |    X    |
# ```
#
# ### Conclusion
# This structured project breakdown and Gantt chart will ensure that each part of the Website project is executed efficiently and on schedule. By meticulously planning each task and maintaining clear deliverables and timelines, the project can achieve its objectives effectively and provide a robust online presence for the small business.
#
#
# # Agent: Expert Estimation Analyst
# ## Task: Thoroughly evaluate each task in the Website project to estimate the time, resources, and effort required. Use historical data, task complexity, and available resources to provide a realistic estimation for each task.
#
#
#
# # Agent: Expert Estimation Analyst
# ## Final Answer:
# ### Detailed Estimation Report for the Website Project
#
# This estimation report outlines the anticipated time, resources, and effort required for each task in the Website project, integrating historical data analysis, task complexity evaluations, and resource availability considerations. Below is the assessment of each major task, including estimated hours, personnel required, and associated risks.
#
# ---
#
# **1. Requirements Analysis and Planning**
# - **Estimated Time:** 40 hours
# - **Resources Needed:** 1 Business Analyst, 1 UX Designer
# - **Effort Complexity:** Low
# - **Deliverables:** Requirements document, wireframes
# - **Risks/Uncertainties:** Delays in stakeholder feedback may extend the timeline.
#
# ---
#
# **2. Design Phase**
# - **Task 2.1: Responsive Design Creation**
#   - **Estimated Time:** 80 hours
#   - **Resources Needed:** 1 UI/UX Designer, 1 Frontend Developer
#   - **Effort Complexity:** Medium
#   - **Deliverables:** Responsive design mockups
#   - **Risks/Uncertainties:** Potential misalignment with initial requirements may necessitate revisions.
#
# - **Task 2.2: User Interface Design**
#   - **Estimated Time:** 80 hours
#   - **Resources Needed:** 1 UI/UX Designer
#   - **Effort Complexity:** Medium
#   - **Deliverables:** UI design specifications
#   - **Risks/Uncertainties:** Design may require multiple iterations based on stakeholder feedback.
#
# - **Task 2.3: Navigation System Design**
#   - **Estimated Time:** 40 hours
#   - **Resources Needed:** 1 UI/UX Designer, 1 Frontend Developer
#   - **Effort Complexity:** Low
#   - **Deliverables:** Navigation flowchart
#   - **Risks/Uncertainties:** Difficulty in achieving intuitive navigation could lead to design flaws.
#
# ---
#
# **3. Development Phase**
# - **Task 3.1: About Us Page Development**
#   - **Estimated Time:** 40 hours
#   - **Resources Needed:** 1 Frontend Developer
#   - **Effort Complexity:** Low
#   - **Deliverables:** About Us page code
#   - **Risks/Uncertainties:** Changes in requirements post-development could require additional effort.
#
# - **Task 3.2: Services Page Development**
#   - **Estimated Time:** 40 hours
#   - **Resources Needed:** 1 Frontend Developer
#   - **Effort Complexity:** Low
#   - **Deliverables:** Services page code
#   - **Risks/Uncertainties:** Potential integration issues with other pages could affect functionality.
#
# - **Task 3.3: Contact Us Page Development**
#   - **Estimated Time:** 40 hours
#   - **Resources Needed:** 1 Frontend Developer
#   - **Effort Complexity:** Medium
#   - **Deliverables:** Contact Us page code
#   - **Risks/Uncertainties:** Embed map functionality might encounter compatibility issues.
#
# - **Task 3.4: Blog Section Development**
#   - **Estimated Time:** 80 hours
#   - **Resources Needed:** 1 Frontend Developer, 1 Backend Developer
#   - **Effort Complexity:** Medium
#   - **Deliverables:** Blog section code
#   - **Risks/Uncertainties:** Integration of backend functionalities may exceed initial estimates.
#
# - **Task 3.5: Testimonials Section Development**
#   - **Estimated Time:** 40 hours
#   - **Resources Needed:** 1 Frontend Developer
#   - **Effort Complexity:** Low
#   - **Deliverables:** Testimonials section code
#   - **Risks/Uncertainties:** Design integration may require additional testing if contingency specifications are not clear.
#
# ---
#
# **4. Testing Phase**
# - **Task 4.1: Quality Assurance Testing**
#   - **Estimated Time:** 80 hours
#   - **Resources Needed:** 1 QA Tester, 1 Frontend Developer
#   - **Effort Complexity:** High
#   - **Deliverables:** QA test report
#   - **Risks/Uncertainties:** Complexity of functionalities may lead to longer testing times than anticipated.
#
# - **Task 4.2: Load and Performance Testing**
#   - **Estimated Time:** 40 hours
#   - **Resources Needed:** 1 QA Tester
#   - **Effort Complexity:** Medium
#   - **Deliverables:** Performance test results
#   - **Risks/Uncertainties:** Performance for various user capacities may not meet thresholds.
#
# ---
#
# **5. Implementation Phase**
# - **Task 5.1: Social Media Integration**
#   - **Estimated Time:** 40 hours
#   - **Resources Needed:** 1 Frontend Developer
#   - **Effort Complexity:** Low
#   - **Deliverables:** Updated website with social media integrations
#   - **Risks/Uncertainties:** Third-party APIs may have unforeseen issues.
#
# - **Task 5.2: Final Review and Launch**
#   - **Estimated Time:** 40 hours
#   - **Resources Needed:** 1 Project Manager, 1 QA Tester
#   - **Effort Complexity:** Low
#   - **Deliverables:** Live website
#   - **Risks/Uncertainties:** Last-minute item reviews may require additional adjustments.
#
# ---
#
# ### Summary of Risks and Uncertainties:
#
# 1. **Stakeholder Delays:** Feedback loops can extend the timeline.
# 2. **Design Revisions:** User interface design may require multiple iterations.
# 3. **Integration Challenges:** Potential issues during the integration of components and features could extend development time.
# 4. **Performance Acceptance:** Load testing outcomes may not met performance expectations, causing further adjustments.
# 5. **Dependency Conflict:** Overlap of tasks requiring shared resources could lead to bottlenecks.
#
# The total estimated timeline for the entire project is approximately 15 weeks, inclusive of all phases from requirements analysis to implementation. The resources identified will vary depending on availability and may result in required adjustments along the way.
#
# By adhering to this estimation report, we position the Website project for success, ensuring efficiency and resource optimization throughout the execution stages.
#
#
# # Agent: Resource Allocation Strategist
# ## Task: Strategically allocate tasks for the Website project to team members based on their skills, availability, and current workload. Ensure that each task is assigned to the most suitable team member and that the workload is evenly distributed.
#
# Team members:
#
# - John Doe (Project Manager)
# - Jane Doe (Software Engineer)
# - Bob Smith (Designer)
# - Alice Johnson (QA Engineer)
# - Tom Brown (QA Engineer)
#
#
#
#
# # Agent: Resource Allocation Strategist
# ## Final Answer:
# ### Resource Allocation Chart for Website Project
#
# | Task                                       | Team Member                  | Start Date | End Date   |
# |--------------------------------------------|------------------------------|------------|------------|
# | Requirements Analysis and Planning         | John Doe (PM)                | Week 1    | Week 2    |
# | Task 2.1: Responsive Design Creation       | Bob Smith (Designer)         | Week 3    | Week 5    |
# | Task 2.2: User Interface Design            | Bob Smith (Designer)         | Week 5    | Week 6    |
# | Task 2.3: Navigation System Design         | Bob Smith (Designer)         | Week 6    | Week 7    |
# | Task 3.1: About Us Page Development       | Jane Doe (Software Engineer) | Week 8    | Week 9    |
# | Task 3.2: Services Page Development       | Jane Doe (Software Engineer) | Week 9    | Week 10   |
# | Task 3.3: Contact Us Page Development     | Jane Doe (Software Engineer) | Week 10   | Week 11   |
# | Task 3.4: Blog Section Development        | Jane Doe (Software Engineer) | Week 11   | Week 13   |
# | Task 3.5: Testimonials Section Development | Jane Doe (Software Engineer) | Week 13   | Week 14   |
# | Task 4.1: Quality Assurance Testing        | Alice Johnson (QA)           | Week 12   | Week 14   |
# | Task 4.2: Load and Performance Testing     | Tom Brown (QA)               | Week 14   | Week 15   |
# | Task 5.1: Social Media Integration         | Jane Doe (Software Engineer) | Week 14   | Week 15   |
# | Task 5.2: Final Review and Launch         | John Doe (PM), Alice Johnson (QA) | Week 15 | Week 15   |
#
# ### Summary of Rationale Behind Each Allocation Decision
#
# 1. **John Doe (Project Manager)** is assigned to lead the **Requirements Analysis and Planning** task as it requires strong leadership to coordinate stakeholder inputs and align the vision early on, ensuring a clear path for the project.
#
# 2. **Bob Smith (Designer)** is responsible for all design phases and tasks (responsive design, UI design, navigation system design) due to his specialization as a designer. The design phases are given adequate time while allowing sequential work to minimize iterations later on.
#
# 3. **Jane Doe (Software Engineer)** is tasked with developing the website's pages (About Us, Services, Contact Us, Blog, Testimonials) as she has the skillset necessary for frontend development. By scheduling these tasks consecutively, she can maintain focus on the development process and leverage any feedback from design directly.
#
# 4. **Alice Johnson (QA Engineer)** is assigned to **Quality Assurance Testing** because she needs to ensure product quality after John and Jane's work is done. Allocating this task ensures that any bugs can be addressed before the integration phase.
#
# 5. **Tom Brown (QA Engineer)** will perform **Load and Performance Testing**, which is crucial after the completion of several development tasks. This timing allows realistic testing scenarios under anticipated load conditions.
#
# 6. **Jane Doe (Software Engineer)** will also handle **Social Media Integration** which is a straightforward task that can seamlessly follow her other development activities, minimizing context-switching.
#
# 7. **Final Review and Launch** involves both John Doe (PM) for leadership and oversight, and Alice Johnson (QA) to ensure that quality checks are thoroughly completed before going live.
#
# This allocation takes into account the team’s skills, availability, and current workloads while evenly distributing tasks to optimize efficiency and enhance project success. By following this strategic task allocation, we can anticipate timely delivery for each project phase within the overall 15 weeks timeline.

# %% [markdown]
# ## Usage Metrics and Costs

# %% [markdown]
# Let’s see how much it would cost each time if this crew runs at scale.

# %%
import pandas as pd

costs = 0.150 * (crew.usage_metrics.prompt_tokens + crew.usage_metrics.completion_tokens) / 1_000_000
print(f"Total costs: ${costs:.4f}")

# Convert UsageMetrics instance to a DataFrame
df_usage_metrics = pd.DataFrame([crew.usage_metrics.dict()])
df_usage_metrics
# Out:
# Total costs: $0.0030
#    total_tokens  prompt_tokens  completion_tokens  successful_requests
# 0         20226          12068               8158                    9

# %% [markdown]
# ## Result

# %%
result.pydantic.dict()
# Out:
# {'tasks': [{'task_name': 'Requirements Analysis and Planning',
#    'estimated_time_hours': 40.0,
#    'required_resources': ['John Doe (PM)']},
#   {'task_name': 'Task 2.1: Responsive Design Creation',
#    'estimated_time_hours': 80.0,
#    'required_resources': ['Bob Smith (Designer)']},
#   {'task_name': 'Task 2.2: User Interface Design',
#    'estimated_time_hours': 40.0,
#    'required_resources': ['Bob Smith (Designer)']},
#   {'task_name': 'Task 2.3: Navigation System Design',
#    'estimated_time_hours': 40.0,
#    'required_resources': ['Bob Smith (Designer)']},
#   {'task_name': 'Task 3.1: About Us Page Development',
#    'estimated_time_hours': 40.0,
#    'required_resources': ['Jane Doe (Software Engineer)']},
#   {'task_name': 'Task 3.2: Services Page Development',
#    'estimated_time_hours': 40.0,
#    'required_resources': ['Jane Doe (Software Engineer)']},
#   {'task_name': 'Task 3.3: Contact Us Page Development',
#    'estimated_time_hours': 40.0,
#    'required_resources': ['Jane Doe (Software Engineer)']},
#   {'task_name': 'Task 3.4: Blog Section Development',
#    'estimated_time_hours': 40.0,
#    'required_resources': ['Jane Doe (Software Engineer)']},
#   {'task_name': 'Task 3.5: Testimonials Section Development',
#    'estimated_time_hours': 40.0,
#    'required_resources': ['Jane Doe (Software Engineer)']},
#   {'task_name': 'Task 4.1: Quality Assurance Testing',
#    'estimated_time_hours': 40.0,
#    'required_resources': ['Alice Johnson (QA)']},
#   {'task_name': 'Task 4.2: Load and Performance Testing',
#    'estimated_time_hours': 40.0,
#    'required_resources': ['Tom Brown (QA)']},
#   {'task_name': 'Task 5.1: Social Media Integration',
#    'estimated_time_hours': 20.0,
#    'required_resources': ['Jane Doe (Software Engineer)']},
#   {'task_name': 'Task 5.2: Final Review and Launch',
#    'estimated_time_hours': 20.0,
#    'required_resources': ['John Doe (PM)', 'Alice Johnson (QA)']}],
#  'milestones': [{'milestone_name': 'Design Phase Complete',
#    'tasks': ['Requirements Analysis and Planning',
#     'Task 2.1: Responsive Design Creation',
#     'Task 2.2: User Interface Design',
#     'Task 2.3: Navigation System Design']},
#   {'milestone_name': 'Development Phase Complete',
#    'tasks': ['Task 3.1: About Us Page Development',
#     'Task 3.2: Services Page Development',
#     'Task 3.3: Contact Us Page Development',
#     'Task 3.4: Blog Section Development',
#     'Task 3.5: Testimonials Section Development']},
#   {'milestone_name': 'Testing Phase Complete',
#    'tasks': ['Task 4.1: Quality Assurance Testing',
#     'Task 4.2: Load and Performance Testing']},
#   {'milestone_name': 'Project Launch',
#    'tasks': ['Task 5.1: Social Media Integration',
#     'Task 5.2: Final Review and Launch']}]}

# %% [markdown]
# ## Inspect further

# %%
tasks = result.pydantic.dict()['tasks']
df_tasks = pd.DataFrame(tasks)

# Display the DataFrame as an HTML table
df_tasks.style.set_table_attributes('border="1"').set_caption("Task Details").set_table_styles(
    [{'selector': 'th, td', 'props': [('font-size', '120%')]}]
)
# Out:
# <style type="text/css">
# #T_0bd2f th {
#   font-size: 120%;
# }
# #T_0bd2f  td {
#   font-size: 120%;
# }
# </style>
# <table id="T_0bd2f" border="1">
#   <caption>Task Details</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0bd2f_level0_col0" class="col_heading level0 col0" >task_name</th>
#       <th id="T_0bd2f_level0_col1" class="col_heading level0 col1" >estimated_time_hours</th>
#       <th id="T_0bd2f_level0_col2" class="col_heading level0 col2" >required_resources</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0bd2f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0bd2f_row0_col0" class="data row0 col0" >Requirements Analysis and Planning</td>
#       <td id="T_0bd2f_row0_col1" class="data row0 col1" >40.000000</td>
#       <td id="T_0bd2f_row0_col2" class="data row0 col2" >['John Doe (PM)']</td>
#     </tr>
#     <tr>
#       <th id="T_0bd2f_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_0bd2f_row1_col0" class="data row1 col0" >Task 2.1: Responsive Design Creation</td>
#       <td id="T_0bd2f_row1_col1" class="data row1 col1" >80.000000</td>
#       <td id="T_0bd2f_row1_col2" class="data row1 col2" >['Bob Smith (Designer)']</td>
#     </tr>
#     <tr>
#       <th id="T_0bd2f_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_0bd2f_row2_col0" class="data row2 col0" >Task 2.2: User Interface Design</td>
#       <td id="T_0bd2f_row2_col1" class="data row2 col1" >40.000000</td>
#       <td id="T_0bd2f_row2_col2" class="data row2 col2" >['Bob Smith (Designer)']</td>
#     </tr>
#     <tr>
#       <th id="T_0bd2f_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_0bd2f_row3_col0" class="data row3 col0" >Task 2.3: Navigation System Design</td>
#       <td id="T_0bd2f_row3_col1" class="data row3 col1" >40.000000</td>
#       <td id="T_0bd2f_row3_col2" class="data row3 col2" >['Bob Smith (Designer)']</td>
#     </tr>
#     <tr>
#       <th id="T_0bd2f_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_0bd2f_row4_col0" class="data row4 col0" >Task 3.1: About Us Page Development</td>
#       <td id="T_0bd2f_row4_col1" class="data row4 col1" >40.000000</td>
#       <td id="T_0bd2f_row4_col2" class="data row4 col2" >['Jane Doe (Software Engineer)']</td>
#     </tr>
#     <tr>
#       <th id="T_0bd2f_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_0bd2f_row5_col0" class="data row5 col0" >Task 3.2: Services Page Development</td>
#       <td id="T_0bd2f_row5_col1" class="data row5 col1" >40.000000</td>
#       <td id="T_0bd2f_row5_col2" class="data row5 col2" >['Jane Doe (Software Engineer)']</td>
#     </tr>
#     <tr>
#       <th id="T_0bd2f_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_0bd2f_row6_col0" class="data row6 col0" >Task 3.3: Contact Us Page Development</td>
#       <td id="T_0bd2f_row6_col1" class="data row6 col1" >40.000000</td>
#       <td id="T_0bd2f_row6_col2" class="data row6 col2" >['Jane Doe (Software Engineer)']</td>
#     </tr>
#     <tr>
#       <th id="T_0bd2f_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_0bd2f_row7_col0" class="data row7 col0" >Task 3.4: Blog Section Development</td>
#       <td id="T_0bd2f_row7_col1" class="data row7 col1" >40.000000</td>
#       <td id="T_0bd2f_row7_col2" class="data row7 col2" >['Jane Doe (Software Engineer)']</td>
#     </tr>
#     <tr>
#       <th id="T_0bd2f_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_0bd2f_row8_col0" class="data row8 col0" >Task 3.5: Testimonials Section Development</td>
#       <td id="T_0bd2f_row8_col1" class="data row8 col1" >40.000000</td>
#       <td id="T_0bd2f_row8_col2" class="data row8 col2" >['Jane Doe (Software Engineer)']</td>
#     </tr>
#     <tr>
#       <th id="T_0bd2f_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_0bd2f_row9_col0" class="data row9 col0" >Task 4.1: Quality Assurance Testing</td>
#       <td id="T_0bd2f_row9_col1" class="data row9 col1" >40.000000</td>
#       <td id="T_0bd2f_row9_col2" class="data row9 col2" >['Alice Johnson (QA)']</td>
#     </tr>
#     <tr>
#       <th id="T_0bd2f_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_0bd2f_row10_col0" class="data row10 col0" >Task 4.2: Load and Performance Testing</td>
#       <td id="T_0bd2f_row10_col1" class="data row10 col1" >40.000000</td>
#       <td id="T_0bd2f_row10_col2" class="data row10 col2" >['Tom Brown (QA)']</td>
#     </tr>
#     <tr>
#       <th id="T_0bd2f_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_0bd2f_row11_col0" class="data row11 col0" >Task 5.1: Social Media Integration</td>
#       <td id="T_0bd2f_row11_col1" class="data row11 col1" >20.000000</td>
#       <td id="T_0bd2f_row11_col2" class="data row11 col2" >['Jane Doe (Software Engineer)']</td>
#     </tr>
#     <tr>
#       <th id="T_0bd2f_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_0bd2f_row12_col0" class="data row12 col0" >Task 5.2: Final Review and Launch</td>
#       <td id="T_0bd2f_row12_col1" class="data row12 col1" >20.000000</td>
#       <td id="T_0bd2f_row12_col2" class="data row12 col2" >['John Doe (PM)', 'Alice Johnson (QA)']</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Inspecting Milestones

# %%
milestones = result.pydantic.dict()['milestones']
df_milestones = pd.DataFrame(milestones)

# Display the DataFrame as an HTML table
df_milestones.style.set_table_attributes('border="1"').set_caption("Task Details").set_table_styles(
    [{'selector': 'th, td', 'props': [('font-size', '120%')]}]
)
# Out:
# <style type="text/css">
# #T_fe1a9 th {
#   font-size: 120%;
# }
# #T_fe1a9  td {
#   font-size: 120%;
# }
# </style>
# <table id="T_fe1a9" border="1">
#   <caption>Task Details</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fe1a9_level0_col0" class="col_heading level0 col0" >milestone_name</th>
#       <th id="T_fe1a9_level0_col1" class="col_heading level0 col1" >tasks</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fe1a9_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_fe1a9_row0_col0" class="data row0 col0" >Design Phase Complete</td>
#       <td id="T_fe1a9_row0_col1" class="data row0 col1" >['Requirements Analysis and Planning', 'Task 2.1: Responsive Design Creation', 'Task 2.2: User Interface Design', 'Task 2.3: Navigation System Design']</td>
#     </tr>
#     <tr>
#       <th id="T_fe1a9_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_fe1a9_row1_col0" class="data row1 col0" >Development Phase Complete</td>
#       <td id="T_fe1a9_row1_col1" class="data row1 col1" >['Task 3.1: About Us Page Development', 'Task 3.2: Services Page Development', 'Task 3.3: Contact Us Page Development', 'Task 3.4: Blog Section Development', 'Task 3.5: Testimonials Section Development']</td>
#     </tr>
#     <tr>
#       <th id="T_fe1a9_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_fe1a9_row2_col0" class="data row2 col0" >Testing Phase Complete</td>
#       <td id="T_fe1a9_row2_col1" class="data row2 col1" >['Task 4.1: Quality Assurance Testing', 'Task 4.2: Load and Performance Testing']</td>
#     </tr>
#     <tr>
#       <th id="T_fe1a9_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_fe1a9_row3_col0" class="data row3 col0" >Project Launch</td>
#       <td id="T_fe1a9_row3_col1" class="data row3 col1" >['Task 5.1: Social Media Integration', 'Task 5.2: Final Review and Launch']</td>
#     </tr>
#   </tbody>
# </table>
